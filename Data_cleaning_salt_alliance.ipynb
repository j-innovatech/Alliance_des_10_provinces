# %% [markdown]
# <a href="https://colab.research.google.com/github/j-innovatech/Salt_Alliance/blob/main/Data_cleaning_salt_alliance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data cleaning for Salt Alliance dataset
# ==============
#
# This notebook process the data from Heurist for further analysis of in J-innvovatech's Salt Alliance project.
#
# This is for a publication proposal for a data paper on ...
#
# Author:
# Hiroki Yamashita (Sciences Po)
#
# This code is constructed in the following way.
#
# 1. Load two json files from the Heurist database. One for meetings and one for actors.
# 2. Split raws of the meeting data so that each raw contains only one actor
# 3. Merge data with actor data so that thier Japanese names as well as domains and provinces are in the data.
# 4. Calculate the number of the time an actor had been to meetings and make a column
# 5. Save the new dataframe in CSV format

# %%
# Import necessary packages
import pandas as pd
import re
import json

# %% [markdown]
# ## Load data
# The following block loads the data from the github repository of J-innovatech at the following adress:
# https://github.com/j-innovatech/Salt_Alliance

# %%
! git clone https://github.com/j-innovatech/Salt_Alliance
path1 = "./Alliance/data/Meetings.json"
path2 = "./Alliance/data/Meetings.json"

# %%
#Place of Meetings
DictMeetingPlace={
    "An.yōji - 安養寺":"Aki",
    "Itsukushima - 厳島":"Aki",
    "Yuga-san - 瑜伽山（由加山）":"Bizen",
    "Marugame - 丸亀":"Sanuki"
}

# %%
# Creating a dataframe for meetings from json file

# Opening JSON file
f = open(path1)
data = json.load(f)

# Columns for the dataframe
Meetings=[]
Actors=[]
DatesJP = [] #field name "Date(s)"
Datedebut=[] #field name "Date greg"
Datefin=[] #field name "Date greg"
DateYears=[]
MeetingPlacesFR = [] #field name "Lieux de réunion"
MeetingPlacesJP = [] #field name "Lieux de réunion"
MeetingProvinces =[]
Sources=[] #field name "Sources"

#Loop for each meeting
for meeting in data["heurist"]["records"]:
  MeetingParticipants=[]
  #Erasing the indent, \n
  MeetingsWithoutIndent =re.sub("[\n]+"," ",meeting["rec_Title"])
  Meetings.append(MeetingsWithoutIndent)

  #Loop for additional information on meeting
  for detail in meeting["details"]:
    if detail["fieldName"]=="Acteur":
      #Erasing the indent, \n
      NameWithoutIndent =re.sub("[\n]+"," ",detail["value"]["title"])
      MeetingParticipants.append(NameWithoutIndent)

    #"Date(s)"
    if detail["fieldName"]=="Date(s)":
      #Erasing the indent, \n
      DateJPWithoutIndent =re.sub("[\n]+"," ",detail["value"]["title"])
      DatesJP.append(DateJPWithoutIndent)

    #"Date greg"
    if detail["fieldName"]=="Date greg":
      if isinstance(detail["value"],dict):
        Datedebut.append(detail["value"]["start"]["earliest"])
        Datefin.append(detail["value"]["end"]["latest"])
        DateYear = re.findall(r"([0-9]{4})",detail["value"]["start"]["earliest"])[0]
        DateYears.append(DateYear)

      else:
        Datedebut.append(detail["value"])
        Datefin.append(detail["value"])
        DateYear = re.findall(r"([0-9]{4})",detail["value"])[0]
        DateYears.append(DateYear)

    #"Lieux de réunion"
    if detail["fieldName"]=="Lieux de réunion":
      MeetingPlacesFR.append(detail["value"]["title"].split(" - ")[0])
      MeetingPlacesJP.append(detail["value"]["title"].split(" - ")[1])
      MeetingProvinces.append(DictMeetingPlace[detail["value"]["title"]])

    #"Sources"
    if detail["fieldName"]=="Sources":
      Sources.append(detail["value"]["title"])

  #Append the list of participants for a meeting
  Actors.append(MeetingParticipants)

df = pd.DataFrame(list(zip(Actors,Meetings,DatesJP,DateYears,Datedebut,Datefin,MeetingPlacesFR,MeetingPlacesJP,MeetingProvinces,Sources)),
               columns =['Acteur', "Description événement","Date JP","Année","Date de debut greg","Date de fin greg","Lieux de réunion FR","Lieux de réunion JP","Province de réunion","Sources"])

#Split raws by actors
df =df.explode("Acteur",ignore_index=True)

#close the json file
f.close()

# %%
# Creating a dataframe for actors from json file

# Opening JSON file of actors
f = open(path2)
data = json.load(f)

# List of actors who went to at least one meeting
Actorslist=list(df["Acteur"].value_counts().index)

# Columns for the dataframe
Actors=[]
Domains=[] #field name "Province ou domaine associé"
Provinces=[] #field name "Province ou domaine associé"
NameFR =[] #field name "Nom acteur fr"
NameJP = [] #field name "Nom acteur JP"
StatusFR1=[]#field name "Statut de l'acteur"
StatusJP1=[]#field name "Statut de l'acteur"
StatusFR2=[]#field name "Statut de l'acteur"
StatusJP2=[]#field name "Statut de l'acteur"
AssociatedSitesFR1 = [] #field name "Site associé"
AssociatedSitesJP1= [] #field name "Site associé"
AssociatedSitesFR2 = [] #field name "Site associé"
AssociatedSitesJP2 = [] #field name "Site associé"
AssociatedSitesFR3 = [] #field name "Site associé"
AssociatedSitesJP3= [] #field name "Site associé"

#Loop each actor
for actor in data["heurist"]["records"]:
  #Erasing the indent, \n
  NameWithoutIndent =re.sub("[\n]+"," ",actor["rec_Title"])

  #Put actor data only if the actor has attended to the meeting in the meeting list
  if NameWithoutIndent in Actorslist:
    Actors.append(NameWithoutIndent)
    #Counter for the number of associated sites and status
    Sitecount=0
    Statuscount=0

    for detail in actor["details"]:
      #"Province ou domaine associé"
      if detail["fieldName"]== "Province ou domaine associé":
        Domains.append(re.findall(r"Hiroshima|Tokushima|Okayama|Hagi|Himeji|Ehime|Iwakuni|Matsuyama|Marugame|Takamatsu|Akō",detail["value"])[0])
        Provinces.append(re.findall(r"Bizen|Iyo|Suō|Awa|Aki|Bizen|Bingo|Settsu|Nagato|Harima|Awaji|Sanuki|Tosa",detail["value"])[0])

      #'Nom acteur fr'
      if detail["fieldName"]== "Nom acteur fr":
        NameFR.append(detail["value"])

      #'Nom acteur JP'
      if detail["fieldName"] == "Nom acteur jap":
        NameJP.append(detail["value"])

      #'Statut de l'acteur'
      if detail["fieldName"] == "Statut de l'acteur":
        Statuscount+=1

        if Statuscount== 1:
          StatusFR1.append(detail["value"]["title"].split(" - ")[0])
          StatusJP1.append(detail["value"]["title"].split(" - ")[1])
        if Statuscount== 2:
          StatusFR2.append(detail["value"]["title"].split(" - ")[0])
          StatusJP2.append(detail["value"]["title"].split(" - ")[1])

      #'Site associé'
      if detail["fieldName"] == "Site associé":
        Sitecount+=1

        # Put the name of the production site depending on the number of sites for an actor
        if Sitecount== 1:
          AssociatedSitesFR1.append(detail["value"]["title"].split(" - ")[0])
          AssociatedSitesJP1.append(detail["value"]["title"].split(" - ")[1])
        if Sitecount== 2:
          AssociatedSitesFR2.append(detail["value"]["title"].split(" - ")[0])
          AssociatedSitesJP2.append(detail["value"]["title"].split(" - ")[1])
        if Sitecount== 3:
          AssociatedSitesFR3.append(detail["value"]["title"].split(" - ")[0])
          AssociatedSitesJP3.append(detail["value"]["title"].split(" - ")[1])

    # Put a blank for status and production site when there is no record
    if Statuscount==0:
      StatusFR1.append("")
      StatusJP1.append("")
      StatusFR2.append("")
      StatusJP2.append("")
    if Statuscount==1:
      StatusFR2.append("")
      StatusJP2.append("")

    if Sitecount== 0:
      AssociatedSitesFR1.append("")
      AssociatedSitesJP1.append("")
      AssociatedSitesFR2.append("")
      AssociatedSitesJP2.append("")
      AssociatedSitesFR3.append("")
      AssociatedSitesJP3.append("")

    if Sitecount== 1:
      AssociatedSitesFR2.append("")
      AssociatedSitesJP2.append("")
      AssociatedSitesFR3.append("")
      AssociatedSitesJP3.append("")

    if Sitecount== 2:
      AssociatedSitesFR3.append("")
      AssociatedSitesJP3.append("")

Actor_df = pd.DataFrame(list(zip(Actors,NameFR,NameJP,Domains,Provinces,StatusFR1,StatusJP1,StatusFR2,StatusJP2,AssociatedSitesFR1,AssociatedSitesJP1,AssociatedSitesFR2,AssociatedSitesJP2,AssociatedSitesFR3,AssociatedSitesJP3)),
                columns =['Acteur', "Nom acteur FR","Nom acteur JP","Domain","Province","Statut de l'acteur FR 1","Statut de l'acteur JP 1","Statut de l'acteur FR 2","Statut de l'acteur JP 2","Site associé FR 1","Site associé JP 1","Site associé FR 2","Site associé JP 2","Site associé FR 3","Site associé JP 3"])

f.close()
# Out:
# Aki dd Hiroshima Ikuchi jima Doiya Kiyoemon
# Aki dd Hiroshima Ikuchi jima Ebisuya Yūta
# Aki dd Hiroshima Ikuchi jima Fukushimaya Tomisuke
# Aki dd Hiroshima Ikuchi jima Hansuke
# Aki dd Hiroshima Ikuchi jima Heisaku
# Aki dd Hiroshima Ikuchi jima Hōkiya Hansuke
# Aki dd Hiroshima Ikuchi jima Kaizō
# Aki dd Hiroshima Ikuchi jima Kasai Moemon
# Aki dd Hiroshima Ikuchi jima Kiinokuniya Heiemon
# Aki dd Hiroshima Ikuchi jima Kiyosuke
# Aki dd Hiroshima Ikuchi jima Koshi Heijūrō
# Aki dd Hiroshima Ikuchi jima Koya Kiheiji
# Aki dd Hiroshima Ikuchi jima Koya Zenbē
# Aki dd Hiroshima Ikuchi jima Messager(Ikuchi jima)
# Aki dd Hiroshima Ikuchi jima Suga Chōjirō
# Aki dd Hiroshima Kairōhama Kōsuke1
# Aki dd Hiroshima Kairōhama Kōsuke2
# Aki dd Hiroshima Kairōhama Kyūemon
# Aki dd Hiroshima Kairōhama Miyake Sen.emon
# Aki dd Hiroshima Kairōhama Nishimotoya Hansuke
# Aki dd Hiroshima Kairōhama Sen.emon
# Aki dd Hiroshima Kairōhama Shōhachi
# Aki dd Hiroshima Kairōhama Takagiya Zenzaburō
# Aki dd Hiroshima Kairōhama Yaemon
# Aki dd Hiroshima Kairōhama Yamanaka Genjirō
# Aki dd Hiroshima Kairōhama Yoshiwaya Kōzō
# Aki dd Hiroshima Setodahama Kiinokuniya Kōhei
# Aki dd Hiroshima Setodahama Nodaya Jingohē
# Aki dd Hiroshima Takehara Chōzaburō
# Aki dd Hiroshima Takehara Daisuke - Nakamayaku  (Ap 1824)
# 1
# Aki dd Hiroshima Takehara Hanayama Sichizaemon
# Aki dd Hiroshima Takehara Hanzaemon - Ancien
# 1
# Aki dd Hiroshima Takehara Hanzō
# Aki dd Hiroshima Takehara Heisa
# Aki dd Hiroshima Takehara Heizaburō
# Aki dd Hiroshima Takehara Hiroshimaya Yasugorō
# Aki dd Hiroshima Takehara Jinjirō - Hamashi  (1824-Ap)
# 1
# Aki dd Hiroshima Takehara Juhē
# Aki dd Hiroshima Takehara Kameya Saburōbē
# Aki dd Hiroshima Takehara Kanjiya Hanzō
# Aki dd Hiroshima Takehara Kanjiya Tazaburō
# Aki dd Hiroshima Takehara Kitayama Naojūrō - Wari-Shōya dōkaku  (1824)
# 1
# Aki dd Hiroshima Takehara Kuiya Isaku
# Aki dd Hiroshima Takehara Kuiya Kisobē
# Aki dd Hiroshima Takehara Kyūemon
# Aki dd Hiroshima Takehara Murakami Jūrōemon
# Aki dd Hiroshima Takehara Nakamura Sanpei
# Aki dd Hiroshima Takehara Nakamuraya Sukezaburō
# Aki dd Hiroshima Takehara Naraya Mon.emon
# Aki dd Hiroshima Takehara Shōichirō
# Aki dd Hiroshima Takehara Tazaburō
# Aki dd Hiroshima Takehara Tejima Hanjirō
# Aki dd Hiroshima Takehara Tejima Ijirō
# Aki dd Hiroshima Takehara Tejima Kijirō
# Aki dd Hiroshima Takehara Tōhei - Chef de village, Shōya  (invalid temporal object)
# 1
# Aki dd Hiroshima Takehara Zeniya Rokuhei - Metsukeyaku Nakamayaku Kentai  (1851)
# 1
# Aki dd Hiroshima Takehara Zeniya Tokubē
# Awa (Tokushima ?) Miharaya Tōkichi
# Awa (Tokushima ?) Sakataya Kihē
# Awa dd Tokushima Kotajima hama Rinjirō
# Awa dd Tokushima Muya Hamaya Kiyozaemon
# Awa dd Tokushima Muya Takebē
# Awa dd Tokushima Muya Tenba Shūemon
# Awa dd Tokushima Saita hama Akita Tōhei
# Awa dd Tokushima Saita hama Arai Kihē
# Awa dd Tokushima Saita hama Einosuke
# Awa dd Tokushima Saita hama Enjirō - Jikishi
# 1
# Awa dd Tokushima Saita hama Hamaya Kiyozaemon
# Awa dd Tokushima Saita hama Kamekichi
# Awa dd Tokushima Saita hama Kihē
# Awa dd Tokushima Saita hama Kyūzaemon
# Awa dd Tokushima Saita hama Masutomi Zen.emon
# Awa dd Tokushima Saita hama Moemon
# Awa dd Tokushima Saita hama Nakai An.emon
# Awa dd Tokushima Saita hama Nakajima Kiemon
# Awa dd Tokushima Saita hama Nakajima Utarō
# Awa dd Tokushima Saita hama Nakajima Yoshiemon
# Awa dd Tokushima Saita hama Okada Heizaburō
# Awa dd Tokushima Saita hama Okawa Gōhei
# Awa dd Tokushima Saita hama Rokubē (remp. Naozaki Rokunosuke) - Remplaçant
# 1
# Awa dd Tokushima Saita hama Sadaemon
# Awa dd Tokushima Saita hama Sadakichi - Représentant, Sōdai
# 1
# Awa dd Tokushima Saita hama Sadayoshi
# Awa dd Tokushima Saita hama Sawayoshi - Jikishi
# 1
# Awa dd Tokushima Saita hama Shimajirō
# Awa dd Tokushima Saita hama Shinohara Yajihē
# Awa dd Tokushima Saita hama Takehira
# Awa dd Tokushima Saita hama Takeichi
# Awa dd Tokushima Saita hama Tsunagi Shūhei
# Awa dd Tokushima Saita hama Yorozuya Kai.emon
# Awa dd Tokushima Saita hama Yoshida Sukedayū
# Awa dd Tokushima Saita hama Yoshida Takesuke
# Awa dd Tokushima Saita hama Zendayū
# Bingo dd Hiroshima Kairōhama Iwamiya Kizaemon
# Bingo dd Hiroshima Kairōhama Ryōjirō
# Bingo dd Hiroshima Kairōhama Yoshiwaya Kōsuke
# Bingo dd Hiroshima Kairōhama Yoshiwaya Yagobē
# Bingo dd Hiroshima Matsunaga Bunsuke
# Bingo dd Hiroshima Matsunaga Hiraiya Magozaburō
# Bingo dd Hiroshima Matsunaga Hiraiya Seizō
# Bingo dd Hiroshima Matsunaga Irieya Sanzaburō
# Bingo dd Hiroshima Matsunaga Ishii Shirōzaburō
# Bingo dd Hiroshima Matsunaga Kanjirō - Hamashi
# 1
# Bingo dd Hiroshima Matsunaga Kuroganeya Yozō
# Bingo dd Hiroshima Matsunaga Matsujirō - Hamayakunin
# 1
# Bingo dd Hiroshima Matsunaga Messager(Matsunaga)
# Bingo dd Hiroshima Matsunaga Nagakumiya Tokuzaburō
# Bingo dd Hiroshima Matsunaga Ōmatsuya Hōta
# Bingo dd Hiroshima Matsunaga Rokubē
# Bingo dd Hiroshima Matsunaga Shiraichi Shinbē
# Bingo dd Hiroshima Matsunaga Sōjūrō
# Bingo dd Hiroshima Matsunaga Tashimaya Jinbē
# Bingo dd Hiroshima Matsunaga Tōbē
# Bingo dd Hiroshima Matsunaga Yamaji (Hitoshi)
# Bingo dd Hiroshima Matsunaga Yamaji Matsujirō
# Bingo dd Hiroshima Matsunaga Yamaya Heibē
# Bingo dd Hiroshima Matsunaga Yamaya Yahei
# Bingo dd Hiroshima Matsunaga Yazaemon
# Bingo dd Hiroshima Matsunaga Yoshinoya Kyūbē
# Bingo dd Hiroshima Matsunaga Yoshisuke
# Bingo dd Hiroshima Nojimahama Doiya Han.emon
# Bingo dd Hiroshima Nojimahama Gengorō
# Bingo dd Hiroshima Nojimahama Kijūrō
# Bingo dd Hiroshima Nojimahama Koya Kisuke
# Bingo dd Hiroshima Nojimahama Sakubē - Représentant, Sōdai
# 1
# Bingo dd Hiroshima Takahama Heiemon
# Bingo dd Hiroshima Takahama Kichibē
# Bingo dd Hiroshima Takahama Kyūbē
# Bingo dd Hiroshima Takehara Heisaku
# Bingo dd Hiroshima Takehara Kiyosuke
# Bingo dd Hiroshima Takehara Nakamura Gizaburō - Shiohama shōya  (1825-App)
# 1
# Bingo dd Hiroshima Takehara Rokurō
# Bingo dd Hiroshima Takehara Sanpei
# Bingo dd Hiroshima Takehara Shiraichiya Jinjirō
# Bingo dd Hiroshima Takehara Yasugorō - Hamashi
# 1
# Bingo dd Hiroshima Ten.nyohama Gonshichi
# Bingo dd Hiroshima Ten.nyohama Kanbē
# Bingo dd Hiroshima Ten.nyohama Kichizaburō
# Bingo dd Hiroshima Ten.nyohama Kiemon
# Bingo dd Hiroshima Ten.nyohama Kihē
# Bingo dd Hiroshima Ten.nyohama Kumatani Naoemon
# Bingo dd Hiroshima Ten.nyohama Kumatani Yūzaburō
# Bingo dd Hiroshima Ten.nyohama Matsuya Jinbē
# Bingo dd Hiroshima Ten.nyohama Matsuya Kanbē
# Bingo dd Hiroshima Ten.nyohama Shimaya Seizaburō
# Bingo dd Hiroshima Ten.nyohama Shiraga Moemon
# Bingo dd Hiroshima Ten.nyohama Shōkichi - Hamashi
# 1
# Bingo dd Hiroshima Ten.nyohama Yūjirō
# Bingo dd Hiroshima Tennyogoe Moemon
# Bingo dd Hiroshima Tennyogoe Naoemon
# Bingo dd Hiroshima Tennyogoe Naosaburō
# Bingo dd Hiroshima Tennyogoe Umizuya Kanbē
# Bingo dd Hiroshima Tomihama Amagaiya Gen.emon - Chef de village, Shōya  (1824)
# 1
# Bingo dd Hiroshima Tomihama Kyūbē
# Bingo dd Hiroshima Tomihama Mata.ichi
# Bingo dd Hiroshima Tomihama Matsu.ura Gijūrō
# Bingo dd Hiroshima Tomihama Sen.nosuke
# Bingo dd Hiroshima Tomihama Sentarō
# Bingo dd Hiroshima Tomihama Shin.ya Kōzaburō - Hamashi
# 1
# Bingo dd Hiroshima Tomihama Shinjirō
# Bingo dd Hiroshima Tomihama Sōjirō - Shōyakaku Nakamayaku  (1851)
# 1
# Bingo dd Hiroshima Tomihama Takada Tsunejirō
# Bingo dd Hiroshima Tomihama Takahara Gen.emon
# Bingo dd Hiroshima Tomihama Tenkaiya Zenpei
# Bingo dd Hiroshima Tomihama Tenman.ya Bōhei
# Bingo dd Hiroshima Tomihama Tenman.ya Jinbē
# Bingo dd Hiroshima Tomihama Tenman.ya Shōzaburō
# Bingo dd Hiroshima Tomihama Yagorō
# Bingo dd Hiroshima Tomihama Sankasho Matsu.uraya Kyūbē
# Bingo dd Hiroshima Tomihama Sankasho Messager
# Bingo dd Hiroshima Tomihama Sankasho Tomishimaya Shōzaburō
# Bingo dd Hiroshima Tomihama, Yoshiwahama, Ten.nyohama Takadajima Saburō - Yoshiwahama Hikiuke
# 1
# Bingo dd Hiroshima Yoshiwahama Aburaya Benzō
# Bingo dd Hiroshima Yoshiwahama Benzō
# Bingo dd Hiroshima Yoshiwahama Kanaya Jutarō
# Bingo dd Hiroshima Yoshiwahama Kihē
# Bingo dd Hiroshima Yoshiwahama Koikeya Ihē
# Bingo dd Hiroshima Yoshiwahama Kunioya (財間）Kozaburō - Nakamayaku, （1861）Tomihama Yohiwahama Ten.nyohama responsable negociations  (1824,1861)
# 1
# 2
# Bingo dd Hiroshima Yoshiwahama Kunioya Kokusaburō
# Bingo dd Hiroshima Yoshiwahama Kyūbē
# Bingo dd Hiroshima Yoshiwahama Matsueya Hon.emon
# Bingo dd Hiroshima Yoshiwahama Messager(Yoshiwahama)
# Bingo dd Hiroshima Yoshiwahama Motosuke
# Bingo dd Hiroshima Yoshiwahama Shin.ya Saizaburō
# Bizen dd Okayama Kojima Miyake Haruzaburō
# Bizen dd Okayama Kojima, Nozakihama Miyake Heizaemon
# Bizen dd Okayama Nozakihama Asahē
# Bizen dd Okayama Nozakihama Hanjirō
# Bizen dd Okayama Nozakihama Horio Jōjirō
# Bizen dd Okayama Nozakihama Kanzaburō
# Bizen dd Okayama Nozakihama Kijirō
# Bizen dd Okayama Nozakihama Kishida Seizaburō
# Bizen dd Okayama Nozakihama Kōzaemon
# Bizen dd Okayama Nozakihama Nozaki Bunzaemon
# Bizen dd Okayama Nozakihama Nozaki Busaburō
# Bizen dd Okayama Nozakihama Nozaki Zaijirō
# Bizen dd Okayama Nozakihama Ogino Kōzaemon
# Bizen dd Okayama Nozakihama Ogino Morijirō
# Bizen dd Okayama Nozakihama Shōzō - Jikishi  (（1841）)
# 1
# Bizen dd Okayama Nozakihama Unshū (?)
# Bizen dd Okayama Nozakihama Zenzaburō
# Bizen dd Okayama Nozakihama, Kojima Heizaemon
# Bizen dd Okayama Nozakihama, Kojima Nozaki Buzaemon
# Bizen dd Okayama Nozakihama, Taimura Taimura Seizaburō
# Hagi, Suō Matsunoya Chōemon
# Hagi, Suō Ōguroya Kyūbē
# Hagi, Suō Aoe Tanaka Kizō - Chef de village, Shōya
# 1
# Hagi, Suō Aoe Tashiroya Uhachi - Propriétaire, Jinushi
# 1
# Hagi, Suō Edomari Furunoya Yoshisuke - Propriétaire, Jinushi
# 1
# Hagi, Suō Edomari Ōguroya Jinzaburō - Ancien
# 1
# Hagi, Suō Furuhama Fujiya Tane.emon - Propriétaire, Jinushi
# 1
# Hagi, Suō Furuhama Isokaneya Shōzaburō - Propriétaire, Jinushi
# 1
# Hagi, Suō Furuhama Matsuzakiya Ichinojō - Propriétaire, Jinushi
# 1
# Hagi, Suō Furuhama Notoya Hikozaemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Furuhama Okinoya Tokuzaemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Furuhama Takegamiya Ichirōemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Furuhama Tomohiro Kiyoemon - Ancien
# 1
# Hagi, Suō Furuhama Tsuruya Kyōemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Furuhama Yoshimura Heigorō - Ancien, Grand Ancien, Ôtoshiyori  (invalid temporal object,1824)
# 1
# 2
# Hagi, Suō Hirao, Furuhama Yoneya Kiyoemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Hirao, Hirao Gokaichi Shimozuma Tarōemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Hirao, Okinohama Tokudaya Shichiemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Nagahama Akimoto Ichiemon - Ogōri Ōjōya
# 1
# Hagi, Suō Nagahama Akimoto Magosuke - Propriétaire, Jinushi
# 1
# Hagi, Suō Nagahama Hirahara Kōzaemon - Ancien
# 1
# Hagi, Suō Nakahama Akawaya Chūbē - Propriétaire, Jinushi
# 1
# Hagi, Suō Nakahama Shin.ya Kōjūrō - Ancien
# 1
# Hagi, Suō Nakahama Yamaguchiya Yaichi - Propriétaire, Jinushi
# 1
# Hagi, Suō Nishi-no-ura Hayashi Kiemon - Chef de village, Shōya
# 1
# Hagi, Suō Nishi-no-ura Hayashi Tõzaburō - Propriétaire, Jinushi
# 1
# Hagi, Suō Nishi-no-ura Iseya Rihē - Ancien
# 1
# Hagi, Suō Ōbama Kaneya Wakichi - Propriétaire, Jinushi
# 1
# Hagi, Suō Ōbama Matsuya Shinsuke - Propriétaire, Jinushi
# 1
# Hagi, Suō Ōbama Miura Genzō - Propriétaire, Jinushi
# 1
# Hagi, Suō Ōbama Nagasakiya Yakichi - Propriétaire, Jinushi
# 1
# Hagi, Suō Ōbama Yoshikawaraya Chobē - Ancien
# 1
# Hagi, Suō Tōnami Nishino Chōzaemon - Ancien
# 1
# Hagi, Suō Tōnami Tomonaga Rokuzaemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Tsuruhama Edoya Isogorō - Ancien
# 1
# Hagi, Suō Tsuruhama Shioya Kakuzaemon - Propriétaire, Jinushi
# 1
# Hagi, Suō Tsuruhama Wakamatsuya Senzaemon - Propriétaire, Jinushi
# 1
# Harima dd Akō Akō Salin non précisé Iichirō
# Harima dd Akō Akō Salin non précisé Mataemon
# Harima dd Akō Akō Salin non précisé Messager(Akō)
# Harima dd Akō Akō Salin non précisé Nom manquant (Akō)(?)
# Harima dd Akō Osaki (Higashi hama) Migaraya Magojūrō
# Harima dd Akō Shinden Gi.ichirō - Ancien
# 1
# Harima dd Akō Shinhama (Higashi hama) Chōjūrō
# Harima dd Akō Shinhama (Higashi hama) Funabiki Seikurō
# Harima dd Akō Shinhama (Higashi hama) Gi.ichirō - Ancien  (invalid temporal object)
# 1
# Harima dd Akō Shinhama (Higashi hama) Kakutarō
# Harima dd Akō Shinhama (Higashi hama) Kawaguchiya Jyūemon - Ancien (Village)
# 1
# Harima dd Akō Shinhama (Higashi hama) Kichiemon
# Harima dd Akō Shinhama (Higashi hama) Kisanji
# Harima dd Akō Shinhama (Higashi hama) Représentant de salins absent ayant envoyé un messager de Shinhama.
# Harima dd Akō Shinhama (Higashi hama) Tabuchi Sanosuke - Hamayakunin
# 1
# Harima dd Akō Shinhama (Higashi hama) Taketarō
# Harima dd Akō Shinhama (Higashi hama) Zenpei
# Harima dd Akō Shinhama (Higashi hama) Zentarō - Ancien
# 1
# Harima dd Akō Shioya (Nishi hama) Genjirō
# Harima dd Akō Shioya (Nishi hama) Gorōemon
# Harima dd Akō Shioya (Nishi hama) Hashimoto Yanosuke - Hamayakunin
# 1
# Harima dd Akō Shioya (Nishi hama) Ichigorō - Chef de village, Shōya
# 1
# Harima dd Akō Shioya (Nishi hama) Katagamiya Hikoemon - Ancien de quartier
# 1
# Harima dd Akō Shioya (Nishi hama) Kuniyoshi
# Harima dd Akō Shioya (Nishi hama) Maeda Yosichirō
# Harima dd Akō Shioya (Nishi hama) Magojirō
# Harima dd Akō Shioya (Nishi hama) Miyake Shiemon
# Harima dd Akō Shioya (Nishi hama) Nakaya　Zentarō
# Harima dd Akō Shioya (Nishi hama) Sahē
# Harima dd Akō Shioya (Nishi hama) Shibahara Kakujirō
# Harima dd Akō Shioya (Nishi hama) Yamamoto Chōjūrō
# Harima dd Akō Shioya (Nishi hama) Zentarō
# Harima dd Akō Shioyamura Arao Iemon
# Harima dd Ehime (Usazaki) Nishihama, Matogata Rishichirō - Représentant, Sōdai
# 1
# Harima dd Ehime Aboshi (village) Fukuchiya Gizaemon
# Harima dd Ehime Aboshi (village) Sōgorō - Représentant, Sōdai
# 1
# Harima dd Ehime Aboshi (village) Zenbē - Représentant, Sōdai
# 1
# Harima dd Ehime Kiba Miki Kinjirō
# Harima dd Ehime Ōshio, Sone, Uozaki (village) Kyūjirō - Représentant, Sōdai
# 1
# Harima dd Ehime Ōshio, Sone, Uozaki (village) Yamamoto Harujūrō - Représentant, Sōdai
# 1
# Harima dd Ehime Usazaki Okigaki Jirōhachi
# Harima dd Ehime Usazaki, Kiba Miki Jizaemon - Représentant, Sōdai
# 1
# Harima dd Himeji (Usazaki) Nishihama, Matogata Kanshichirō - Représentant, Sōdai
# 1
# Harima dd Himeji Aboshi (village) Maruo Rokubē
# Harima dd Himeji Kiba Hashimotoya Jūbē
# Harima dd Himeji Kiba Kanbara（？） Masaemon
# Harima dd Himeji Kiba Kanzawa Mataemon
# Harima dd Himeji Kiba Miki Yahē
# Harima dd Himeji Kiba Nagase Matajūrō
# Harima dd Himeji Kiba Nagase Shichikurō
# Harima dd Himeji Kiba Nakajima Tomehachi
# Harima dd Himeji Kiba Nakaya Matazaemon
# Harima dd Himeji Kiba Nakaya Saburōemon
# Harima dd Himeji Matogata Konishi Riemon
# Harima dd Himeji Matogata Nakaya Eshichi
# Harima dd Himeji Matogata Nakaya Tarōzaemon
# Harima dd Himeji Matogata Shioya Kyūbē
# Harima dd Himeji Matogata Tadaya Bunbē
# Harima dd Himeji Matogata Ueda Tōshichirō
# Harima dd Himeji Matogata Yoneya Jūemon
# Harima dd Himeji Ōshio Izawa Sanjirō
# Harima dd Himeji Ōshio Kajihara Jūkurō
# Harima dd Himeji Ōshio Kajiwara Shirōbē
# Harima dd Himeji Ōshio Kurokawa Rihēe
# Harima dd Himeji Ōshio Tanaka Shichirōemon
# Harima dd Himeji Ōshio Yamamoto Anzaemon
# Harima dd Himeji Ōshio Yamamoto Jisaku
# Harima dd Himeji Ōshio Yamamoto Kyūgorō
# Harima dd Himeji Ōshio Yamashiroya Zenjirō
# Harima dd Himeji Ōshio Yoneya Sasuke
# Harima dd Himeji Ōshio Yoneya Shō.ichiemon
# Harima dd Himeji Ōshio Yorozuya Sanjūrō
# Harima dd Himeji Sone, Ōshio, Uozaki (village) Hamanaka San.emon - Représentant, Sōdai
# 1
# Harima dd Himeji Usazaki Iyoya Matazaburō
# Harima dd Himeji Usazaki Kawazaki Sashichirō
# Harima dd Himeji Usazaki Noguchiya Jirōzaemon
# Harima dd Himeji Usazaki Okishio Jiryōhachi
# Harima dd Himeji Usazaki Okishio Kyūsaku
# Harima dd Himeji Usazaki Okizawa Jirōhachi
# Harima dd Himeji Usazaki Sakaya Jūsuke
# Harima dd Himeji Yakahama Shin.ya Jyūdayū
# Iwakuni, Suō Hirata Fujiya Kanzaemon - Propriétaire, Jinushi
# 1
# Iwakuni, Suō Hirata Furuya Ichirōemon - Propriétaire, Jinushi
# 1
# Iyo dd Matsuyama Hashihama Furukawaya Mohē
# Iyo dd Matsuyama Hashihama Nishimoto Tōzaburō
# Iyo dd Matsuyama Hashihama Ōzawa Tsune.emon
# Iyo dd Matsuyama Hashihama Ōzuya Kyūzaemon
# Iyo dd Matsuyama Hashihama Seisichi
# Iyo dd Matsuyama Hashihama Shōji
# Iyo dd Matsuyama Hashihama Tsuyoji (?)
# Iyo dd Matsuyama Hashihama Watanabe Gengo
# Sanuki dd Marugame Nishi Takuma Hama Matsuda Hide.emon
# Sanuki dd Takamatsu Sakaide hama Kichizaburō - Représentant, Sōdai
# 1
# Sanuki dd Takamatsu Sakaide hama Miyazaki Komakichi
# Sanuki dd Takamatsu Sakaide hama Momosuke （Miyazaki Komakichi） - Envoyé
# 1
# Suō dd Hagi Furuhama, Mitajiri Fujimoto Kōsuke - Grand Ancien, Ôtoshiyori  (1803-1810)
# 1
# Suō dd Hagi Furuhama, Mitajiri Fujimoto Kōsuke 2 - Grand Ancien, Ôtoshiyori  (1810)
# 1
# Suō dd Hagi Mitajiri Aritomi Kiyoemon - Grand Ancien, Ôtoshiyori  (1808-1810)
# 1
# Suō dd Hagi Mitajiri Fujimoto Eizō
# Suō dd Hagi Mitajiri Hashimotoya Rihē
# Suō dd Hagi Mitajiri Itō Shōjirō
# Suō dd Hagi Mitajiri Jūzaburō - Naodachi
# 1
# Suō dd Hagi Mitajiri Kanbē - Naodachi
# 1
# Suō dd Hagi Mitajiri Kashiwaya Rihē
# Suō dd Hagi Mitajiri Kazubē(?) - Naodachi
# 1
# Suō dd Hagi Mitajiri Miki Shōzaburō
# Suō dd Hagi Mitajiri Mitsumoto Shõzaburō
# Suō dd Hagi Mitajiri Sakamura Kiyoemon
# Suō dd Hagi Mitajiri Takemura Toshiemon
# Suō dd Hagi Mitajiri Tanaka Seitarō
# Suō dd Hagi Mitajiri Tanaka Tōroku　（1861）
# Suō dd Hagi Mitajiri Tokuhisa Chōbē
# Suō dd Hagi Mitajiri Tokunaga Chōbē - Grand Ancien, Ôtoshiyori  (invalid temporal object)
# 1
# Suō dd Hagi Mitajiri Wakimoto Shiemon
# Suō dd Hagi Mitajiri Yoshida Heigorō
# Suō dd Hagi Mitajiri, Furuhama Tanaka Ya.ichi - Grand Ancien, Ôtoshiyori  (1791-1803)
# 1
# Suō dd Hagi Mitajiri, Furuhama Yoshimura Kizaemon - Grand Ancien, Ôtoshiyori  (1788-1791)
# 1
# Suō dd Hagi Mitajiri, Ōbama Matsumura Yasubē - Grand Ancien, Ôtoshiyori  (1791-1808)
# 1
# Suō dd Hagi Mitajiri, Ōbama Yoshitake Jūzō - Grand Ancien, Ôtoshiyori, Ancien  (1810,1808)
# 1
# 2

# %%
# Merge datafrane for meetings and actors

df = df.merge(Actor_df,left_on ="Acteur",right_on="Acteur", how ="left")

# %%
# Create a new column with number of times an actor have been to a meeting
Actors=df["Acteur"].value_counts().index
N_participation=df["Acteur"].value_counts().values

df["Participation"] = 0
for i, actor in enumerate (Actors):
  df.sort_values(by="Année",inplace=True)
  df.loc[df["Acteur"]==actor,"Participation"]= range(1, N_participation[i] + 1)

# Create a new column for checking if the province of meeting and the actor is the same
df["Même province"] = False
df.loc[df["Province"]==df["Province de réunion"],"Même province"] = True

# %%
# Save the dataframe to CSV
df.to_csv("Salt_alliance_cleaned.csv",index=False)

# %%
len(df)
# Out:
# 473
